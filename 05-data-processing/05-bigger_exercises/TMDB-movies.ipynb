# %% [markdown]
# # TMDB movies

# %% [markdown]
# Load all the necessary packages

# %%
import pandas as pd
import numpy as np
import ast
import matplotlib.pyplot as plt

# %% [markdown]
# The TMDB movies dataset contains detailed information about movies including ratings, financials, crew, cast, language, genres, and production details.
#
# ### Loading the data
#
# Load the dataset into a DataFrame named `df_movies` and inspect the first rows of the DataFrame.

# %%
df = pd.read_csv('TMDB-movies-small.csv', index_col=0)
df_movies = pd.DataFrame(df)
df_movies
# Out:
#              id                                       title  vote_average  \
# 11           16                          Dancer in the Dark         7.868
# 26           55                               Amores Perros         7.600
# 31           64                                 Talk to Her         7.579
# 32           65                                      8 Mile         7.134
# 38           71                                Billy Elliot         7.600
# ...         ...                                         ...           ...
# 885549  1235881           Unfaithful wife, sticky and messy         6.000
# 888337  1239240                                        Love         8.000
# 892747  1244331                         El insan we al fnar         8.000
# 896385  1248655                                  Dog's Home         9.000
# 906093  1259749  Live At The Pop In Paris France 18.12.2002        10.000
#
#         vote_count    status release_date      revenue  runtime      budget  \
# 11            1697  Released   2000-09-01   40061153.0    140.0  12500000.0
# 26            2475  Released   2000-06-16   20908467.0    154.0   2000000.0
# 31            1233  Released   2002-03-15   64803131.0    112.0         NaN
# 32            6958  Released   2002-11-08  242875078.0    111.0  41000000.0
# 38            3691  Released   2000-09-28  109280263.0    110.0   5000000.0
# ...            ...       ...          ...          ...      ...         ...
# 885549           1  Released   2002-04-26          NaN     47.0         NaN
# 888337           1  Released   2000-01-01          NaN      6.0         NaN
# 892747           1  Released   2002-01-01          NaN     24.0         NaN
# 896385           1  Released   2000-10-01          NaN     85.0         NaN
# 906093           1  Released   2002-12-18          NaN     30.0         NaN
#
#            imdb_id  ...                genres  \
# 11       tt0168629  ...          Drama, Crime
# 26       tt0245712  ...       Drama, Thriller
# 31       tt0287467  ...        Drama, Romance
# 32       tt0298203  ...          Drama, Music
# 38       tt0249462  ...  Drama, Comedy, Music
# ...            ...  ...                   ...
# 885549   tt7486670  ...               Romance
# 888337  tt15750744  ...             Animation
# 892747         NaN  ...                   NaN
# 896385   tt0265493  ...                 Drama
# 906093         NaN  ...                 Music
#
#                                      production_companies  \
# 11      Lantia Cinema & Audiovisivi, Fine Line Feature...
# 26                             Altavista Films, Zeta Film
# 31        Vía Digital, Good Machine, El Deseo, Atresmedia
# 32              Mikona Productions, Imagine Entertainment
# 38      StudioCanal, BBC Film, Tiger Aspect, Arts Coun...
# ...                                                   ...
# 885549                                   Shintoho Company
# 888337                                    Studio ""Shar""
# 892747                                                NaN
# 896385                             Filmmaker Features LLC
# 906093                                                NaN
#
#                                      production_countries  spoken_languages  \
# 11      Argentina, Denmark, Finland, France, Germany, ...           English
# 26                                                 Mexico           Español
# 31                                                  Spain           Español
# 32                      Germany, United States of America           English
# 38       France, United Kingdom, United States of America           English
# ...                                                   ...               ...
# 885549                                              Japan               日本語
# 888337                                             Russia           Pусский
# 892747                                                NaN           العربية
# 896385                                                NaN    български език
# 906093                                                NaN               NaN
#
#                                                      cast  \
# 11      Bobo Eriksson, Caroline Sascha Cogez, Bo Weste...
# 26      Gerardo Campbell, Rosa María Bianchi, Ricardo ...
# 31      Carlos García Cambero, Leonor Watling, Pina Ba...
# 32      Malik Barnhardt, Mike Bell, Allen Adams, Abdul...
# 38      Lee Williams, Colin MacLachlan, Neil North, Pa...
# ...                                                   ...
# 885549  Tomohiro Okada, Yasuhiro Asai, Yohta Kawase, Y...
# 888337                                                NaN
# 892747                                                NaN
# 896385  Georgi Kurkelanov, Nikolai Binev, Dossio Dosse...
# 906093                    Solange Gularte, Mehdi Ameziane
#
#                            director director_of_photography  \
# 11                   Lars von Trier            Robby Müller
# 26      Alejandro González Iñárritu          Rodrigo Prieto
# 31                  Pedro Almodóvar    Javier Aguirresarobe
# 32                    Curtis Hanson          Rodrigo Prieto
# 38                   Stephen Daldry            Brian Tufano
# ...                             ...                     ...
# 885549              Akira Fukamachi                     NaN
# 888337              Agamurad Amanov                     NaN
# 892747                 Mohsen Sabry                     NaN
# 896385           Stephan Komandarev       Vladimir Mihaylov
# 906093                          NaN                     NaN
#
#                      writers  \
# 11      Sjón, Lars von Trier
# 26         Guillermo Arriaga
# 31           Pedro Almodóvar
# 32              Scott Silver
# 38                  Lee Hall
# ...                      ...
# 885549             Teruo Oka
# 888337                   NaN
# 892747                   NaN
# 896385          Yurii Dachev
# 906093                   NaN
#
#                                                 producers  \
# 11      Leo Pescarolo, Peter Aalbæk Jensen, Vibeke Win...
# 26      Martha Sosa Elizondo, Francisco González Compe...
# 31                        Michel Ruben, Agustín Almodóvar
# 32      Jimmy Iovine, Jim Whitaker, Brian Grazer, Greg...
# 38      Jonathan Finn, Natascha Wharton, Tessa Ross, D...
# ...                                                   ...
# 885549                                                NaN
# 888337                                                NaN
# 892747                                                NaN
# 896385                                Christopher Bojilov
# 906093                                                NaN
#
#                          music_composer
# 11                                Björk
# 26                  Gustavo Santaolalla
# 31      Alberto Iglesias, Vicente Amigo
# 32                                  NaN
# 38                      Stephen Warbeck
# ...                                 ...
# 885549                              NaN
# 888337                              NaN
# 892747                              NaN
# 896385                              NaN
# 906093                              NaN
#
# [9392 rows x 25 columns]

# %% [markdown]
# ### Top movies in 2000

# %% [markdown]
# Create a new DataFrame `df_2000` with all movies released in the year 2000. Inspect the amount of rows in the new DataFrame.

# %%
df_movies['release_date'] = pd.to_datetime(df_movies['release_date'], format="%Y-%m-%d")
df_2000 = df_movies.loc[df_movies['release_date'].dt.year == 2000]
df_2000
# Out:
#              id                                              title  \
# 11           16                                 Dancer in the Dark
# 26           55                                      Amores Perros
# 38           71                                       Billy Elliot
# 43           77                                            Memento
# 63           98                                          Gladiator
# ...         ...                                                ...
# 868959  1215684                       Jerusalem: The Covenant City
# 881800  1231307  In the Shadow of the Vampire: The Making of In...
# 885541  1235872               In love with a naughty gold princess
# 888337  1239240                                               Love
# 896385  1248655                                         Dog's Home
#
#         vote_average  vote_count    status release_date      revenue  runtime  \
# 11             7.868        1697  Released   2000-09-01   40061153.0    140.0
# 26             7.600        2475  Released   2000-06-16   20908467.0    154.0
# 38             7.600        3691  Released   2000-09-28  109280263.0    110.0
# 43             8.184       14320  Released   2000-10-11   40000000.0    113.0
# 63             8.200       17788  Released   2000-05-04  465361176.0    155.0
# ...              ...         ...       ...          ...          ...      ...
# 868959         5.000           1  Released   2000-04-09          NaN    107.0
# 881800         6.000           1  Released   2000-01-01          NaN     30.0
# 885541         8.000           1  Released   2000-10-28          NaN     52.0
# 888337         8.000           1  Released   2000-01-01          NaN      6.0
# 896385         9.000           1  Released   2000-10-01          NaN     85.0
#
#              budget     imdb_id  ...                    genres  \
# 11       12500000.0   tt0168629  ...              Drama, Crime
# 26        2000000.0   tt0245712  ...           Drama, Thriller
# 38        5000000.0   tt0249462  ...      Drama, Comedy, Music
# 43        9000000.0   tt0209144  ...         Mystery, Thriller
# 63      103000000.0   tt0172495  ...  Action, Drama, Adventure
# ...             ...         ...  ...                       ...
# 868959    1000000.0  tt30400786  ...      Documentary, History
# 881800          NaN         NaN  ...               Documentary
# 885541          NaN   tt4138394  ...                   Romance
# 888337          NaN  tt15750744  ...                 Animation
# 896385          NaN   tt0265493  ...                     Drama
#
#                                      production_companies  \
# 11      Lantia Cinema & Audiovisivi, Fine Line Feature...
# 26                             Altavista Films, Zeta Film
# 38      StudioCanal, BBC Film, Tiger Aspect, Arts Coun...
# 43      Summit Entertainment, Newmarket Capital Group,...
# 63      Universal Pictures, Scott Free Productions, Re...
# ...                                                   ...
# 868959             Lance Lambert Ministries, Vision Video
# 881800                                                NaN
# 885541                                   Shintoho Company
# 888337                                    Studio ""Shar""
# 896385                             Filmmaker Features LLC
#
#                                      production_countries  spoken_languages  \
# 11      Argentina, Denmark, Finland, France, Germany, ...           English
# 26                                                 Mexico           Español
# 38       France, United Kingdom, United States of America           English
# 43                               United States of America           English
# 63               United Kingdom, United States of America           English
# ...                                                   ...               ...
# 868959                           United States of America           English
# 881800                           United States of America           English
# 885541                                              Japan               日本語
# 888337                                             Russia           Pусский
# 896385                                                NaN    български език
#
#                                                      cast  \
# 11      Bobo Eriksson, Caroline Sascha Cogez, Bo Weste...
# 26      Gerardo Campbell, Rosa María Bianchi, Ricardo ...
# 38      Lee Williams, Colin MacLachlan, Neil North, Pa...
# 43      Carrie-Anne Moss, Callum Keith Rennie, Jorja F...
# 63      Brian Smyj, Russell Crowe, John Shrapnel, Paul...
# ...                                                   ...
# 868959     Gershon Salomon, Roger Climpson, Lance Lambert
# 881800  Stan Winston, Anne Rice, Kirsten Dunst, Stephe...
# 885541  Yôko Satomi, Hiroyuki Kawasaki, Mayuko Sasaki,...
# 888337                                                NaN
# 896385  Georgi Kurkelanov, Nikolai Binev, Dossio Dosse...
#
#                            director director_of_photography  \
# 11                   Lars von Trier            Robby Müller
# 26      Alejandro González Iñárritu          Rodrigo Prieto
# 38                   Stephen Daldry            Brian Tufano
# 43                Christopher Nolan           Wally Pfister
# 63                     Ridley Scott          John Mathieson
# ...                             ...                     ...
# 868959                  Hugh Kitson                     NaN
# 881800                          NaN                     NaN
# 885541              Akira Fukamachi                     NaN
# 888337              Agamurad Amanov                     NaN
# 896385           Stephan Komandarev       Vladimir Mihaylov
#
#                                               writers  \
# 11                               Sjón, Lars von Trier
# 26                                  Guillermo Arriaga
# 38                                           Lee Hall
# 43                  Jonathan Nolan, Christopher Nolan
# 63      William Nicholson, David Franzoni, John Logan
# ...                                               ...
# 868959                                    Hugh Kitson
# 881800                                            NaN
# 885541                                            NaN
# 888337                                            NaN
# 896385                                   Yurii Dachev
#
#                                                 producers  \
# 11      Leo Pescarolo, Peter Aalbæk Jensen, Vibeke Win...
# 26      Martha Sosa Elizondo, Francisco González Compe...
# 38      Jonathan Finn, Natascha Wharton, Tessa Ross, D...
# 43               Jennifer Todd, Suzanne Todd, Aaron Ryder
# 63      Walter F. Parkes, Branko Lustig, Ridley Scott,...
# ...                                                   ...
# 868959                         Hugh Kitson, Lance Lambert
# 881800                                                NaN
# 885541                                                NaN
# 888337                                                NaN
# 896385                                Christopher Bojilov
#
#                    music_composer
# 11                          Björk
# 26            Gustavo Santaolalla
# 38                Stephen Warbeck
# 43                   David Julyan
# 63      Lisa Gerrard, Hans Zimmer
# ...                           ...
# 868959                        NaN
# 881800                        NaN
# 885541                        NaN
# 888337                        NaN
# 896385                        NaN
#
# [2850 rows x 25 columns]

# %% [markdown]
# Create a new DataFrame `df_topmovies` which only incorporates the rows with the movies of the year 2000 who get an average score of at least 9. Compare the total amount of rows of the original dataframe with these of df_topmovies.

# %%
df_topmovies = pd.DataFrame(df_2000[df_2000['vote_average'] >= 9])
df_topmovies
# Out:
#              id                              title  vote_average  vote_count  \
# 17027     28002                      Lazarus Lives          10.0           1
# 18982     30553    Emperor: Emperial Live Ceremony          10.0           1
# 23609     37664             Eurythmics - Peacetour           9.0           2
# 38178     55698         Escape to Grizzly Mountain          10.0           1
# 40712     59077    Une Femme Taxi à Sidi Bel Abbès          10.0           1
# ...         ...                                ...           ...         ...
# 817045  1150924   Morten og peter - ikke helt gak!          10.0           1
# 820190  1154916  Chikan torakku: Injo norippanashi           9.5           1
# 828664  1166244                      Mai dire 2000          10.0           1
# 860724  1206012                              Sissy           9.0           1
# 896385  1248655                         Dog's Home           9.0           1
#
#           status release_date  revenue  runtime  budget    imdb_id  ...  \
# 17027   Released   2000-06-01      NaN      NaN     NaN  tt0956174  ...
# 18982   Released   2000-05-15      NaN     61.0     NaN  tt0380345  ...
# 23609   Released   2000-07-20      NaN     96.0     NaN  tt0273197  ...
# 38178   Released   2000-03-14      NaN     95.0     NaN        NaN  ...
# 40712   Released   2000-07-03      NaN     52.0     NaN  tt0267997  ...
# ...          ...          ...      ...      ...     ...        ...  ...
# 817045  Released   2000-01-13      NaN      0.0     NaN        NaN  ...
# 820190  Released   2000-09-05      NaN     60.0     NaN  tt4135778  ...
# 828664  Released   2000-12-27      NaN     46.0     NaN        NaN  ...
# 860724  Released   2000-01-01      NaN     27.0     NaN        NaN  ...
# 896385  Released   2000-10-01      NaN     85.0     NaN  tt0265493  ...
#
#                                 genres  \
# 17027                Animation, Family
# 18982                            Music
# 23609                            Music
# 38178   Fantasy, Drama, Family, Comedy
# 40712                      Documentary
# ...                                ...
# 817045                     Documentary
# 820190                 Romance, Comedy
# 828664                          Comedy
# 860724                     Documentary
# 896385                           Drama
#
#                                      production_companies  \
# 17027   Rich Animation Studios, NEST Family Entertainm...
# 18982                                 Wildcat Productions
# 23609                                                 BMG
# 38178                            MGM Family Entertainment
# 40712     Les Films de la Passerelle, Machaho Productions
# ...                                                   ...
# 817045                                               TV 2
# 820190                                                NaN
# 828664                                                NaN
# 860724   Reel Images, Australian Broadcasting Corporation
# 896385                             Filmmaker Features LLC
#
#             production_countries  spoken_languages  \
# 17027   United States of America           English
# 18982     Norway, United Kingdom           English
# 23609             United Kingdom           English
# 38178   United States of America               NaN
# 40712           Algeria, Belgium           العربية
# ...                          ...               ...
# 817045                   Denmark             Dansk
# 820190                     Japan               日本語
# 828664                     Italy          Italiano
# 860724                 Australia               NaN
# 896385                       NaN    български език
#
#                                                      cast            director  \
# 17027   Karen Kondazian, Ann Marie Lee, Andrew Craig, ...        Richard Rich
# 18982   Charmand Grimloch, Jan Erik Tiwaz, Vegard Sver...                 NaN
# 23609                          Annie Lennox, Dave Stewart       David Barnard
# 38178   Charlotte Dodds, Miko Hughes, Dan Haggerty, Cy...  Anthony Dalesandro
# 40712                                                 NaN    Belkacem Hadjadj
# ...                                                   ...                 ...
# 817045                                                NaN                 NaN
# 820190   Motoko Sasaki, Masanori Machida, Sheena Nagamori    Kazuyoshi Sekine
# 828664   Giorgio Gherarducci, Carlo Taranto, Marco Santin   Andrea Fantonelli
# 860724  Anna Mae, Charles Colbung, John Collard, John ...      Debbie Gittens
# 896385  Georgi Kurkelanov, Nikolai Binev, Dossio Dosse...  Stephan Komandarev
#
#        director_of_photography  \
# 17027                      NaN
# 18982                      NaN
# 23609                      NaN
# 38178             Steve Adcock
# 40712                      NaN
# ...                        ...
# 817045                     NaN
# 820190                     NaN
# 828664                     NaN
# 860724      Leighton De Barros
# 896385       Vladimir Mihaylov
#
#                                                   writers  \
# 17027                                        Brian Nissen
# 18982                                                 NaN
# 23609                                                 NaN
# 38178   Eric Parkinson, Beau Bauman, Lisa Dalesandro, ...
# 40712                                    Belkacem Hadjadj
# ...                                                   ...
# 817045                                                NaN
# 820190                                                NaN
# 828664                                                NaN
# 860724                                     Debbie Gittens
# 896385                                       Yurii Dachev
#
#                                                 producers music_composer
# 17027       Jared F. Brown, Richard Rich, Seldon O. Young            NaN
# 18982                                                 NaN            NaN
# 23609                           Geoff Foulkes, Mark Harry            NaN
# 38178   Herb Linsey, Tony Cataldo, Menahem Golan, Geor...            NaN
# 40712                                   Christine Pireaux            NaN
# ...                                                   ...            ...
# 817045                                                NaN            NaN
# 820190                                                NaN            NaN
# 828664                                                NaN            NaN
# 860724                         David Jowsey, Brian Beaton            NaN
# 896385                                Christopher Bojilov            NaN
#
# [185 rows x 25 columns]

# %% [markdown]
# In `df_topmovies`, only include the movies with a valid release date and runtime.

# %%
df_topmovies['runtime'].dropna()
df_topmovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 17027 to 896385
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       185 non-null    int64
#  1   title                    185 non-null    object
#  2   vote_average             185 non-null    float64
#  3   vote_count               185 non-null    int64
#  4   status                   185 non-null    object
#  5   release_date             185 non-null    datetime64[ns]
#  6   revenue                  3 non-null      float64
#  7   runtime                  184 non-null    float64
#  8   budget                   8 non-null      float64
#  9   imdb_id                  120 non-null    object
#  10  original_language        185 non-null    object
#  11  original_title           185 non-null    object
#  12  overview                 160 non-null    object
#  13  popularity               185 non-null    float64
#  14  tagline                  37 non-null     object
#  15  genres                   149 non-null    object
#  16  production_companies     94 non-null     object
#  17  production_countries     120 non-null    object
#  18  spoken_languages         126 non-null    object
#  19  cast                     156 non-null    object
#  20  director                 139 non-null    object
#  21  director_of_photography  26 non-null     object
#  22  writers                  81 non-null     object
#  23  producers                52 non-null     object
#  24  music_composer           10 non-null     object
#  25  final_run                185 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(18)
# memory usage: 39.0+ KB

# %% [markdown]
# Add a column "final_run" displaying the last day the film was screened in theaters.

# %%
df_2000['runtime'] = pd.to_datetime(df_2000['runtime'])
df_2000

# df_2000['final_run'] = run
# df_2000
# Out:
# C:\Users\soule\AppData\Local\Temp\ipykernel_20456\4224629027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2000['runtime'] = pd.to_datetime(df_2000['runtime'])
#              id                                              title  \
# 11           16                                 Dancer in the Dark
# 26           55                                      Amores Perros
# 38           71                                       Billy Elliot
# 43           77                                            Memento
# 63           98                                          Gladiator
# ...         ...                                                ...
# 868959  1215684                       Jerusalem: The Covenant City
# 881800  1231307  In the Shadow of the Vampire: The Making of In...
# 885541  1235872               In love with a naughty gold princess
# 888337  1239240                                               Love
# 896385  1248655                                         Dog's Home
#
#         vote_average  vote_count    status release_date      revenue  \
# 11             7.868        1697  Released   2000-09-01   40061153.0
# 26             7.600        2475  Released   2000-06-16   20908467.0
# 38             7.600        3691  Released   2000-09-28  109280263.0
# 43             8.184       14320  Released   2000-10-11   40000000.0
# 63             8.200       17788  Released   2000-05-04  465361176.0
# ...              ...         ...       ...          ...          ...
# 868959         5.000           1  Released   2000-04-09          NaN
# 881800         6.000           1  Released   2000-01-01          NaN
# 885541         8.000           1  Released   2000-10-28          NaN
# 888337         8.000           1  Released   2000-01-01          NaN
# 896385         9.000           1  Released   2000-10-01          NaN
#
#                              runtime       budget     imdb_id  ...  \
# 11     1970-01-01 00:00:00.000000140   12500000.0   tt0168629  ...
# 26     1970-01-01 00:00:00.000000154    2000000.0   tt0245712  ...
# 38     1970-01-01 00:00:00.000000110    5000000.0   tt0249462  ...
# 43     1970-01-01 00:00:00.000000113    9000000.0   tt0209144  ...
# 63     1970-01-01 00:00:00.000000155  103000000.0   tt0172495  ...
# ...                              ...          ...         ...  ...
# 868959 1970-01-01 00:00:00.000000107    1000000.0  tt30400786  ...
# 881800 1970-01-01 00:00:00.000000030          NaN         NaN  ...
# 885541 1970-01-01 00:00:00.000000052          NaN   tt4138394  ...
# 888337 1970-01-01 00:00:00.000000006          NaN  tt15750744  ...
# 896385 1970-01-01 00:00:00.000000085          NaN   tt0265493  ...
#
#                                      production_companies  \
# 11      Lantia Cinema & Audiovisivi, Fine Line Feature...
# 26                             Altavista Films, Zeta Film
# 38      StudioCanal, BBC Film, Tiger Aspect, Arts Coun...
# 43      Summit Entertainment, Newmarket Capital Group,...
# 63      Universal Pictures, Scott Free Productions, Re...
# ...                                                   ...
# 868959             Lance Lambert Ministries, Vision Video
# 881800                                                NaN
# 885541                                   Shintoho Company
# 888337                                    Studio ""Shar""
# 896385                             Filmmaker Features LLC
#
#                                      production_countries spoken_languages  \
# 11      Argentina, Denmark, Finland, France, Germany, ...          English
# 26                                                 Mexico          Español
# 38       France, United Kingdom, United States of America          English
# 43                               United States of America          English
# 63               United Kingdom, United States of America          English
# ...                                                   ...              ...
# 868959                           United States of America          English
# 881800                           United States of America          English
# 885541                                              Japan              日本語
# 888337                                             Russia          Pусский
# 896385                                                NaN   български език
#
#                                                      cast  \
# 11      Bobo Eriksson, Caroline Sascha Cogez, Bo Weste...
# 26      Gerardo Campbell, Rosa María Bianchi, Ricardo ...
# 38      Lee Williams, Colin MacLachlan, Neil North, Pa...
# 43      Carrie-Anne Moss, Callum Keith Rennie, Jorja F...
# 63      Brian Smyj, Russell Crowe, John Shrapnel, Paul...
# ...                                                   ...
# 868959     Gershon Salomon, Roger Climpson, Lance Lambert
# 881800  Stan Winston, Anne Rice, Kirsten Dunst, Stephe...
# 885541  Yôko Satomi, Hiroyuki Kawasaki, Mayuko Sasaki,...
# 888337                                                NaN
# 896385  Georgi Kurkelanov, Nikolai Binev, Dossio Dosse...
#
#                            director director_of_photography  \
# 11                   Lars von Trier            Robby Müller
# 26      Alejandro González Iñárritu          Rodrigo Prieto
# 38                   Stephen Daldry            Brian Tufano
# 43                Christopher Nolan           Wally Pfister
# 63                     Ridley Scott          John Mathieson
# ...                             ...                     ...
# 868959                  Hugh Kitson                     NaN
# 881800                          NaN                     NaN
# 885541              Akira Fukamachi                     NaN
# 888337              Agamurad Amanov                     NaN
# 896385           Stephan Komandarev       Vladimir Mihaylov
#
#                                               writers  \
# 11                               Sjón, Lars von Trier
# 26                                  Guillermo Arriaga
# 38                                           Lee Hall
# 43                  Jonathan Nolan, Christopher Nolan
# 63      William Nicholson, David Franzoni, John Logan
# ...                                               ...
# 868959                                    Hugh Kitson
# 881800                                            NaN
# 885541                                            NaN
# 888337                                            NaN
# 896385                                   Yurii Dachev
#
#                                                 producers  \
# 11      Leo Pescarolo, Peter Aalbæk Jensen, Vibeke Win...
# 26      Martha Sosa Elizondo, Francisco González Compe...
# 38      Jonathan Finn, Natascha Wharton, Tessa Ross, D...
# 43               Jennifer Todd, Suzanne Todd, Aaron Ryder
# 63      Walter F. Parkes, Branko Lustig, Ridley Scott,...
# ...                                                   ...
# 868959                         Hugh Kitson, Lance Lambert
# 881800                                                NaN
# 885541                                                NaN
# 888337                                                NaN
# 896385                                Christopher Bojilov
#
#                    music_composer final_run
# 11                          Björk     141.0
# 26            Gustavo Santaolalla     170.0
# 38                Stephen Warbeck     138.0
# 43                   David Julyan     124.0
# 63      Lisa Gerrard, Hans Zimmer     159.0
# ...                           ...       ...
# 868959                        NaN     116.0
# 881800                        NaN      31.0
# 885541                        NaN      80.0
# 888337                        NaN       7.0
# 896385                        NaN      86.0
#
# [2850 rows x 26 columns]

# %% [markdown]
# Show how many films were released each month using a barplot.
# * Use appropriate labels and titles
# * Change the ticks and tick labels so every month has a tick and as label the abbreviation of the month (Jan, Feb, March etc.)
# * Change the color of the graph
# * Show a grid
# * Show the legend

# %% [markdown]
# ### All movies

# %% [markdown]
# For the following questions, work with the dataframe `df_movies`.
#
# Extract following information from the release date and store this in new columns:
#     day of the week, day of the month, month, year

# %% [markdown]
# Create a new column `profit`, derived from subtracting the budget from the revenue. Remove all rows which do not contain valid revenue or budget data. Also create a column with booleans indicating wheter a film `is_profitable` (profit >0) or not.

# %% [markdown]
# **What are the top 10 most frequent genres?**
#
# We are looking for the individual values, not the unique entries of genre combinations. It should be clear that you will have to do some data manipulations in order to get the answer.
#
# To get you started: When analysing the video games dataset, we have seen a method to create separate rows (each with the same index) to represent multiple values of a column. This method takes a list-like object as argument.
#
# Tip: tackle this assignment step by step.

# %% [markdown]
# **Number of actors and budget**
#
#
# Plot the data so we can visually evaluate whether there seems a relation between the number of actors playing in a movie and the budget of the movie. Create a new_dataframe containing only the relevant columns.

# %% [markdown]
# Create the same plot but now only containing the data of movies who's budget did not exceed 20 000 000.

# %% [markdown]
# **Votes**
#
#
# Show the total number of votes for the year with the most releases.

# %% [markdown]
# More exercises? Feel free to explore the dataset further.
