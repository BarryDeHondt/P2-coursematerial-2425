# %%
import pandas as pd

# %%
df = pd.read_csv('Electric_Vehicle.csv', sep=",", index_col=False)

# %%
idx = df['VIN (1-10)']

df.index = idx

# %%
df.index.name = None
df
# Out:
#             VIN (1-10)     County         City State  Postal Code  Model Year  \
# 2T3YL4DV0E  2T3YL4DV0E       King     Bellevue    WA      98005.0        2014
# 5YJ3E1EB6K  5YJ3E1EB6K       King      Bothell    WA      98011.0        2019
# 5UX43EU02S  5UX43EU02S   Thurston      Olympia    WA      98502.0        2025
# JTMAB3FV5R  JTMAB3FV5R   Thurston      Olympia    WA      98513.0        2024
# 5YJYGDEE8M  5YJYGDEE8M     Yakima        Selah    WA      98942.0        2021
# ...                ...        ...          ...   ...          ...         ...
# 5YJ3E1EA3K  5YJ3E1EA3K       King       Renton    WA      98058.0        2019
# 1GKB0RDC1R  1GKB0RDC1R  Snohomish    Snohomish    WA      98290.0        2024
# 7SAYGDED3R  7SAYGDED3R       King      Redmond    WA      98033.0        2024
# JTMEB3FV5P  JTMEB3FV5P     Chelan  Leavenworth    WA      98826.0        2023
# 5YJYGDEE3M  5YJYGDEE3M     Kitsap    Bremerton    WA      98312.0        2021
#
# ...

# %%
df.drop(columns='VIN (1-10)', inplace=True)
df
# Out:
#                County         City State  Postal Code  Model Year    Make  \
# 2T3YL4DV0E       King     Bellevue    WA      98005.0        2014  TOYOTA
# 5YJ3E1EB6K       King      Bothell    WA      98011.0        2019   TESLA
# 5UX43EU02S   Thurston      Olympia    WA      98502.0        2025     BMW
# JTMAB3FV5R   Thurston      Olympia    WA      98513.0        2024  TOYOTA
# 5YJYGDEE8M     Yakima        Selah    WA      98942.0        2021   TESLA
# ...               ...          ...   ...          ...         ...     ...
# 5YJ3E1EA3K       King       Renton    WA      98058.0        2019   TESLA
# 1GKB0RDC1R  Snohomish    Snohomish    WA      98290.0        2024     GMC
# 7SAYGDED3R       King      Redmond    WA      98033.0        2024   TESLA
# JTMEB3FV5P     Chelan  Leavenworth    WA      98826.0        2023  TOYOTA
# 5YJYGDEE3M     Kitsap    Bremerton    WA      98312.0        2021   TESLA
#
#                     Model                   Electric Vehicle Type  \
# ...

# %%
print(df[df['Model Year'] < 2023])
# Out:
#                County            City State  Postal Code  Model Year  \
# 2T3YL4DV0E       King        Bellevue    WA      98005.0        2014
# 5YJ3E1EB6K       King         Bothell    WA      98011.0        2019
# 5YJYGDEE8M     Yakima           Selah    WA      98942.0        2021
# 3C3CFFGE1G   Thurston         Olympia    WA      98501.0        2016
# 5YJ3E1EA4J  Snohomish      Marysville    WA      98271.0        2018
# ...               ...             ...   ...          ...         ...
# JTDKN3DPXC  Penobscot          Brewer    ME       4412.0        2012
# 1G1RD6E4XE    Douglas  East Wenatchee    WA      98802.0        2014
# JA4J24A52J    Pacific      Ocean Park    WA      98640.0        2018
# 5YJ3E1EA3K       King          Renton    WA      98058.0        2019
# 5YJYGDEE3M     Kitsap       Bremerton    WA      98312.0        2021
#
#                   Make          Model                   Electric Vehicle Type  \
# ...

# %%
df.rename(columns={'Make':'Brand'}, inplace=True)
df
# Out:
#                County         City State  Postal Code  Model Year   Brand  \
# 2T3YL4DV0E       King     Bellevue    WA      98005.0        2014  TOYOTA
# 5YJ3E1EB6K       King      Bothell    WA      98011.0        2019   TESLA
# 5UX43EU02S   Thurston      Olympia    WA      98502.0        2025     BMW
# JTMAB3FV5R   Thurston      Olympia    WA      98513.0        2024  TOYOTA
# 5YJYGDEE8M     Yakima        Selah    WA      98942.0        2021   TESLA
# ...               ...          ...   ...          ...         ...     ...
# 5YJ3E1EA3K       King       Renton    WA      98058.0        2019   TESLA
# 1GKB0RDC1R  Snohomish    Snohomish    WA      98290.0        2024     GMC
# 7SAYGDED3R       King      Redmond    WA      98033.0        2024   TESLA
# JTMEB3FV5P     Chelan  Leavenworth    WA      98826.0        2023  TOYOTA
# 5YJYGDEE3M     Kitsap    Bremerton    WA      98312.0        2021   TESLA
#
#                     Model                   Electric Vehicle Type  \
# ...

# %%
print(df.groupby(['Brand']).count())
# Out:
#                         County   City  State  Postal Code  Model Year  Model  \
# Brand
# ACURA                      175    175    175          175         175    175
# ALFA ROMEO                  95     95     95           95          95     95
# AUDI                      4286   4286   4286         4286        4286   4286
# AZURE DYNAMICS               4      4      4            4           4      4
# BENTLEY                      5      5      5            5           5      5
# BMW                       9503   9503   9505         9503        9505   9505
# BRIGHTDROP                   5      5      5            5           5      5
# CADILLAC                  1107   1107   1107         1107        1107   1107
# CHEVROLET                16919  16919  16919        16919       16919  16919
# CHRYSLER                  3773   3773   3773         3773        3773   3773
# DODGE                      766    766    766          766         766    766
# ...

# %%
df.groupby(['Model']).count()
# Out:
#        County  City  State  Postal Code  Model Year  Brand  \
# Model
# 330E      504   504    504          504         504    504
# 500       715   715    715          715         715    715
# 500E       55    55     55           55          55     55
# 530E      435   435    437          435         437    437
# 550E        4     4      4            4           4      4
# ...       ...   ...    ...          ...         ...    ...
# XC60     1579  1579   1579         1579        1579   1579
# XC90     1986  1986   1986         1986        1986   1986
# XM         23    23     23           23          23     23
# ZDX       175   175    175          175         175    175
# ZEVO        5     5      5            5           5      5
#
#        Electric Vehicle Type  \
# Model
# 330E                     504
# 500                      715
# 500E                      55
# 530E                     437
# 550E                       4
# ...                      ...
# ...

# %%
df.groupby('Model Year')['Electric Vehicle Type'].count()
# Out:
# Model Year
# 1999        2
# 2000        7
# 2002        2
# 2003        1
# 2008       22
# 2010       23
# 2011      692
# 2012     1523
# 2013     4263
# 2014     3432
# 2015     4688
# 2016     5375
# 2017     8551
# 2018    14298
# 2019    10965
# 2020    12248
# 2021    20565
# 2022    28930
# 2023    59808
# 2024    47920
# 2025     8915
# Name: Electric Vehicle Type, dtype: int64
