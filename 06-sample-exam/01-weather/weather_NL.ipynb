# %% [markdown]
# # Data analyse: Het weer
# In het bestand `weather_dataset.csv`vind je weergegevens van verschillende steden. Jouw taak is om deze data op te schonen en te analyseren. Gebruik de voorziene code-velden onder de opdrachten om je code in te schrijven.

# %% [markdown]
# Importeer de packages die je nodig hebt.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# * Importeer de weergegevens in een DataFrame met de naam `df_weather`.
# * Inspecteer het DataFrame door de eerste 10 rijen te tonen (gebruik hiervoor geen slicing).

# %%
df_weather = pd.read_csv('weather_dataset.csv', sep=',', index_col=False)
df_weather.head(10)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
# 5  20000106      1                  3            0.85          1.0244
# 6  20000107      1                  8            0.84          1.0267
# 7  20000108      1                  4            0.79          1.0248
# 8  20000109      1                  8            0.88          1.0243
# 9  20000110      1                  8            0.91          1.0337
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
# 5                    0.56                 0.00             5.7
# 6                    0.20                 0.00             0.0
# 7                    0.54                 0.00             4.3
# 8                    0.11                 0.65             0.0
# 9                    0.06                 0.09             0.0
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# 1              3.6             2.7  ...                 0.5
# 2              2.2             0.1  ...                -1.0
# 3              3.9             0.5  ...                 2.5
# 4              6.0             3.8  ...                -1.8
# 5              4.2             1.9  ...                -0.6
# 6              4.7             1.8  ...                 1.7
# 7              5.6             4.1  ...                 3.5
# 8              4.6             3.8  ...                 3.3
# 9              2.4             1.4  ...                 0.0
#
#    STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                 0.7               1.6            0.97          1.0275
# 1                 2.0               2.0            0.99          1.0293
# 2                 2.8               3.4            0.91          1.0267
# 3                 4.6               4.9            0.95          1.0222
# 4                 2.9               3.6            0.95          1.0209
# 5                 4.0               3.4            0.92          1.0209
# 6                 4.1               2.8            0.96          1.0258
# 7                 6.4               3.6            0.97          1.0210
# 8                 5.1               3.0            0.91          1.0280
# 9                 5.5               1.9            0.94          1.0369
#
#    TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                    0.25                 0.04              8.5
# 1                    0.17                 0.16              7.9
# 2                    0.27                 0.00              8.1
# 3                    0.11                 0.44              8.6
# 4                    0.39                 0.04              8.0
# 5                    0.55                 0.20              7.1
# 6                    0.27                 0.00              6.0
# 7                    0.18                 0.14              8.2
# 8                    0.43                 0.02              5.6
# 9                    0.58                 0.04              1.8
#
#    TOURS_temp_min  TOURS_temp_max
# 0             7.2             9.8
# 1             6.6             9.2
# 2             6.6             9.6
# 3             6.4            10.8
# 4             6.4             9.5
# 5             3.5            10.7
# 6             3.3             8.8
# 7             5.3            11.0
# 8             3.7             7.6
# 9            -1.5             5.0
#
# [10 rows x 165 columns]

# %% [markdown]
# * Verander de data ('datums'/meervoud van datum) in de DATE kolom in pandas datetime objects.
# * Enkel de rijen met data uit 2009 moeten in het dataframe worden opgenomen.

# %%
df_weather["DATE"] = pd.to_datetime(df_weather["DATE"], format="%Y%m%d")

df_weather = df_weather[df_weather["DATE"].dt.year == 2009]

df_weather
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3288 2009-01-01      1                  4            0.84          1.0284
# 3289 2009-01-02      1                  8            0.89          1.0262
# 3290 2009-01-03      1                  5            0.72          1.0263
# 3291 2009-01-04      1                  4            0.75          1.0239
# 3292 2009-01-05      1                  8            0.84          1.0197
# ...         ...    ...                ...             ...             ...
# 3648 2009-12-27     12                  7            0.80          1.0118
# 3649 2009-12-28     12                  7            0.82          1.0084
# 3650 2009-12-29     12                  7            0.92          1.0028
# 3651 2009-12-30     12                  8            0.92          0.9979
# 3652 2009-12-31     12                  7            0.93          0.9958
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3288                    0.63                 0.00             7.1
# 3289                    0.07                 0.00             0.0
# 3290                    0.50                 0.00             2.9
# 3291                    0.62                 0.00             5.4
# 3292                    0.28                 0.05             0.0
# ...                      ...                  ...             ...
# 3648                    0.37                 0.18             2.3
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 3288              1.5             0.2  ...                -6.0
# 3289             -1.0            -1.8  ...                -8.1
# 3290             -3.1            -6.2  ...                -5.8
# 3291             -3.7            -6.5  ...               -10.8
# 3292             -4.1            -6.4  ...               -12.6
# ...               ...             ...  ...                 ...
# 3648              1.0            -3.9  ...                -7.7
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 3288                -1.9               4.9            0.92          1.0259
# 3289                -4.6               4.9            0.93          1.0245
# 3290                -2.7               6.0            0.79          1.0236
# 3291                -5.8               1.9            0.86          1.0231
# 3292                -8.3               2.0            0.92          1.0181
# ...                  ...               ...             ...             ...
# 3648                -2.7               4.6            0.84          1.0091
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 3288                    0.22                 0.00              0.6
# 3289                    0.08                 0.00             -0.4
# 3290                    0.69                 0.00             -0.1
# 3291                    0.68                 0.00             -2.4
# 3292                    0.18                 0.16             -4.4
# ...                      ...                  ...              ...
# 3648                    0.58                 0.08              4.6
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
#
#       TOURS_temp_min  TOURS_temp_max
# 3288            -0.5             1.7
# 3289            -1.1             0.4
# 3290            -1.4             1.1
# 3291            -5.3             0.5
# 3292            -6.9            -1.9
# ...              ...             ...
# 3648            -0.5             9.7
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
#
# [365 rows x 165 columns]

# %% [markdown]
# * Verwijder de rijen met NaN-waarden

# %%
df_weather = df_weather.dropna()
df_weather
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3288 2009-01-01      1                  4            0.84          1.0284
# 3289 2009-01-02      1                  8            0.89          1.0262
# 3290 2009-01-03      1                  5            0.72          1.0263
# 3291 2009-01-04      1                  4            0.75          1.0239
# 3292 2009-01-05      1                  8            0.84          1.0197
# ...         ...    ...                ...             ...             ...
# 3648 2009-12-27     12                  7            0.80          1.0118
# 3649 2009-12-28     12                  7            0.82          1.0084
# 3650 2009-12-29     12                  7            0.92          1.0028
# 3651 2009-12-30     12                  8            0.92          0.9979
# 3652 2009-12-31     12                  7            0.93          0.9958
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3288                    0.63                 0.00             7.1
# 3289                    0.07                 0.00             0.0
# 3290                    0.50                 0.00             2.9
# 3291                    0.62                 0.00             5.4
# 3292                    0.28                 0.05             0.0
# ...                      ...                  ...             ...
# 3648                    0.37                 0.18             2.3
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 3288              1.5             0.2  ...                -6.0
# 3289             -1.0            -1.8  ...                -8.1
# 3290             -3.1            -6.2  ...                -5.8
# 3291             -3.7            -6.5  ...               -10.8
# 3292             -4.1            -6.4  ...               -12.6
# ...               ...             ...  ...                 ...
# 3648              1.0            -3.9  ...                -7.7
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 3288                -1.9               4.9            0.92          1.0259
# 3289                -4.6               4.9            0.93          1.0245
# 3290                -2.7               6.0            0.79          1.0236
# 3291                -5.8               1.9            0.86          1.0231
# 3292                -8.3               2.0            0.92          1.0181
# ...                  ...               ...             ...             ...
# 3648                -2.7               4.6            0.84          1.0091
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 3288                    0.22                 0.00              0.6
# 3289                    0.08                 0.00             -0.4
# 3290                    0.69                 0.00             -0.1
# 3291                    0.68                 0.00             -2.4
# 3292                    0.18                 0.16             -4.4
# ...                      ...                  ...              ...
# 3648                    0.58                 0.08              4.6
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
#
#       TOURS_temp_min  TOURS_temp_max
# 3288            -0.5             1.7
# 3289            -1.1             0.4
# 3290            -1.4             1.1
# 3291            -5.3             0.5
# 3292            -6.9            -1.9
# ...              ...             ...
# 3648            -0.5             9.7
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
#
# [365 rows x 165 columns]

# %% [markdown]
# * Maak 4 verschillende DataFrames aan, één voor elk van deze steden: Basel, Oslo, Roma en Maastricht. Geef ze respectievelijk volgende namen: `df_Basel`, `df_Oslo`, `df_Roma` en `df_Maastricht`.
# * Elk dataframe moet de kolom met de datum en de maand bevatten en al de kolommen met de gegevens van de betreffende stad.

# %%
basel_cols = ['DATE', 'MONTH'] + [col for col in df_weather.columns if col.startswith('BASEL_')]
oslo_cols = ['DATE', 'MONTH'] + [col for col in df_weather.columns if col.startswith('OSLO_')]
roma_cols = ['DATE', 'MONTH'] + [col for col in df_weather.columns if col.startswith('ROMA_')]
maastricht_cols = ['DATE', 'MONTH'] + [col for col in df_weather.columns if col.startswith('MAASTRICHT_')]

df_Basel = df_weather[basel_cols].copy()
df_Oslo = df_weather[oslo_cols].copy()
df_Roma = df_weather[roma_cols].copy()
df_Maastricht = df_weather[maastricht_cols].copy()

for df in [df_Basel, df_Oslo, df_Roma, df_Maastricht]:
    df["DATE"] = pd.to_datetime(df["DATE"], format="%Y%m%d")

# %% [markdown]
# ### Maastricht
# Teken een grafiek met daarop volgende informatie over de temperatuurmetingen in de loop van de tijd in Maastricht:
# * Temperatuur in °C wordt op de y-as getoond
# * Gemiddelde temperatuur in het oranje (orange)
# * Max temperatuur in rood (red)
# * Min temperatuur in blauw (blue)
# * Toon ook een legende met gepaste labels die aanduiden welke data er wordt getoond
# * Zorg voor correcte as-labels en titel
# * Zorg dat er voor elke maand een markering is op de x-as. Label deze met de afkorting voor de maanden (jan, feb, maart etc. )

# %%
months = [month[:3] if len(month) > 5 else month for month in df_Maastricht["DATE"].dt.month_name().unique()]
ticks = ["2009-0" + str(i) if i <10 else "2009-"+str(i) for i in range(1,13)]
ticks
# range(1, len(df_Maastricht["MONTH"].unique()) + 1)
# Out:
# ['2009-01',
#  '2009-02',
#  '2009-03',
#  '2009-04',
#  '2009-05',
#  '2009-06',
#  '2009-07',
#  '2009-08',
#  '2009-09',
#  '2009-10',
#  '2009-11',
#  '2009-12']

# %%
plt.figure(figsize=(10,6))

plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_mean"], color="orange", label = "mean temp")
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_max"], color="red", label = "max temp")
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_min"], color="blue", label = "mintemp")

plt.title("Temperatuur in Maastricht")

plt.xlabel('Month')
plt.ylabel('Temperature in C')

plt.xticks(ticks= ticks, labels=months)

plt.legend()
plt.show()

# %% [markdown]
# ### Mean temperatures
# Gemiddelde temperatuur
#
# Maak een nieuwe grafiek met de gemiddelde temperatuur gemeten in de loop van de tijd in de steden waarvoor je aparte dataframes hebt gemaakt. Temperatuur wordt in graden Celcius weergegeven op de y-as.
#
# * Maastricht in oranje (orange)
# * Roma in rood (red)
# * Basel in groen (green)
# * Oslo in blauw (blue)
# * Toon een legende met gepaste labels die duidelijk maken welke gegevens worden getoond
# * Zorg voor correcte as-labels en titel
# * Voorzie markeringen voor elke maand op de x-as, gelabeld met de afkorting van de maanden (jan, feb, maart etc.)
# * Toon een raster (grid)

# %%
plt.figure(figsize=(10,6))

plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_mean"], color="orange", label = "mean temp Maastricht")
plt.plot(df_Oslo["DATE"], df_Oslo["OSLO_temp_mean"], color="blue", label = "mean temp Oslo")
plt.plot(df_Roma["DATE"], df_Roma["ROMA_temp_mean"], color="red", label = "mean temp Roma")
plt.plot(df_Basel["DATE"], df_Basel["BASEL_temp_mean"], color="green", label = "mean temp Basel")

plt.title("Gemiddelde Temperatuur")

plt.xlabel('Month')
plt.ylabel('Temperature in C')

plt.xticks(ticks= ticks, labels=months)

plt.legend()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# Controleer je werk grondig en zorg ervoor dat je alle opdrachten hebt gemaakt.
# Er zijn geen testen voorzien voor deze data analyse oefening. Zorg ervoor dat je de juiste namen hebt gebruikt.

# %% [markdown]
# ___
